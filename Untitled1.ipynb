# %%
import pyluos
from pyluos import Device
device = Device ('/dev/cu.usbmodem142302')
print(device.nodes)
print(device.services)
# Out:
# Connected to "/dev/cu.usbmodem142302".
# Sending detection signal.
# Waiting for routing table...
# Device setup.
#   ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
#   ┃  ╭node 1            /!\ Not certified            ┃
#   ┃  │  Type                Alias               ID   ┃
#   ┃  ├> Pipe                Pipe                2    ┃
#   ┃  ├> Gate                gate                1    ┃
#   ┃  ╰> Unknown             lcd                 3    ┃
# ╔>┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# -------------------------------------------------
# Type                Alias               ID
# -------------------------------------------------
# Pipe                Pipe                2
# Gate                gate                1
# Unknown             lcd                 3

# %%
print(device.lcd.parameters.blink)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-045ff97127d0> in <module>
# ----> 1 print(device.lcd.parameters.blink)
#
# AttributeError: 'int' object has no attribute 'blink'
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/marie/Downloads/Pyluos-rc-2.0.0/pyluos/io/serial_io.py", line 90, in _poll
#     to_read = self._serial.in_waiting
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/serial/serialposix.py", line 549, in in_waiting
#     s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
# ...

# %%
device.servo.rot_position = 100
# Out:
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/marie/Downloads/Pyluos-rc-2.0.0/pyluos/io/serial_io.py", line 90, in _poll
#     to_read = self._serial.in_waiting
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/serial/serialposix.py", line 549, in in_waiting
#     s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
# OSError: [Errno 6] Device not configured

# %%
print(device.services)
# Out:
# -------------------------------------------------
# Type                Alias               ID
# -------------------------------------------------
# Pipe                Pipe                2
# Gate                gate                1
# ServoMotor          servo               3

# %%
print(device.servo.rot_position)
# Out:
# 0.0
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# ...

# %%
device.servo.target_rot_position = 0
# Out:
# rotation position mode could be not enabled in the service please use 'device.service.rot_position_mode = True' to enable it
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# Msg read failed: Invalid control character at: line 1 column 11 (char 10)
# ...

# %%
print(device.servo.rot_position)
# Out:
# 0.0
# Msg read failed: Invalid control character at: line 1 column 4 (char 3)
# Msg read failed: Invalid control character at: line 1 column 28 (char 27)
# Msg read failed: Invalid control character at: line 1 column 6 (char 5)
# Msg read failed: Invalid control character at: line 1 column 30 (char 29)
# Msg read failed: Invalid control character at: line 1 column 8 (char 7)
# Msg read failed: Invalid control character at: line 1 column 32 (char 31)
# Msg read failed: Invalid control character at: line 1 column 10 (char 9)
# Msg read failed: Invalid control character at: line 1 column 34 (char 33)
# Msg read failed: Invalid control character at: line 1 column 12 (char 11)
# Msg read failed: Invalid control character at: line 1 column 36 (char 35)
# Msg read failed: Expecting value: line 1 column 13 (char 12)
# Msg read failed: Expecting ':' delimiter: line 1 column 37 (char 36)
# Msg read failed: Invalid control character at: line 1 column 16 (char 15)

# %%
print
